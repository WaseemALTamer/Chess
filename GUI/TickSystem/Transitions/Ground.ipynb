# %%
from EaseInOut import EaseInOut


u = Uniform()
u.starting_value = 10
u.ending_value = 20
u.duration = 10

# %%
def fun(value):
    print(value)


u.on_update_callbacks.append(fun)

# %%
u.start_tranition()

# %%
u.reverse_transition()

# %%
u.update()
