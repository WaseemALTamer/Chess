# %%
class Piece:
    # Per-type constants
    base_move_rays: list[list[tuple[int, int]]] = []
    value: int = 0
    blocked_by_pieces: bool = True
    can_jump_over_pieces: bool = False

    def __init__(self):
        self.color: str | None = None



class King(Piece):
    def __init__(self):
        super().__init__()
        self.value = 0

# %%
k1 = King()
k1.color = "BLACK"
k2 = King()
k2.color = "WHITE"

# %%
k2.Color

# %%
def test(text):
    print(text)


x = lambda: test("hello there")

# %%
x.__

# %%
from Board import Board
from Rules import Rules

b = Board()
b.setup_classic()

# %%
Rules.calculate_all_legal_moves(b)

# %%
b.grid[3][0].possible_moves
# Out:
# [(0, 4)]

# %%
b.print_grid()
# Out:
# Rock        Knight      Bishop      Queen       King        Bishop      Knight      Rock
# .           Pawn        Pawn        Pawn        Pawn        Pawn        Pawn        Pawn
# GhostPawn   .           .           .           .           .           .           .
# Pawn        .           .           .           .           .           .           .
# .           .           .           .           .           .           .           .
# .           .           .           .           .           .           .           .
# Pawn        Pawn        Pawn        Pawn        Pawn        Pawn        Pawn        Pawn
# Rock        Knight      Bishop      Queen       King        Bishop      Knight      Rock

# %%
Rules.apply_move(b, (0, 1), (0, 3))

# %%
b.grid[5][0].kill_trigger()

# %%
Rules.age_and_cleanup_pieces(b)

# %%
Rules.apply_move(b, (0, 4), (0, 3))

# %%
Rules.calculate_piece_moves(b, (0, 3))

# %%
b.get_piece((0, 3)).base_move_rays

# %%
(1, 2) + (2, 1)

# %%
_base_move_rays = [
    [(0, -1), (0, -2)],
]


rays = [
    _base_move_rays[0][0]
]
rays
